# %% [markdown]
# ## Table of Content
# 1. **[Data Structures with Examples](#Data_Structures)**
# 2. **[Create and Manipulate the DataFrames](#create_manipulate)**
# 3. **[Sort](#sorting)**
# 4. **[Rank](#ranking)**

# %% [markdown]
# ### Let's begin with some hands-on practice exercises

# %% [markdown]
# <a id='Data_Structures'></a>
# ## 1. Data Structures with Examples:

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>1. Write a program to create a dataframe from list of lists
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the below nested list:**<br>
#
#         data = [['Joy', 21], ['Mia', 15], ['Sam', 14]]

# %%
import pandas as pd
data = [['Joy', 21], ['Mia', 15], ['Sam', 14]]
df1=pd.DataFrame(data)
df1
# Out:
#      0   1
# 0  Joy  21
# 1  Mia  15
# 2  Sam  14

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>2. Extract the second word from the given string
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the below string:**<br>
#
#     sentence = 'Be confident and be yourself'

# %%
sentence = 'Be confident and be yourself'
df2 = pd.DataFrame(sentence.split())
df2[1:2]
# Out:
#            0
# 1  confident

# %% [markdown]
# <a id='create_manipulate'></a>
# ## 2. Create and Manipulate the DataFrames:

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>3. Split the 'Name' column into two separate columns as First_Name and Last_Name </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Salary</th>
# </tr>
# <tr>
# <td>Emma Larter</td>
# <td>3200</td>
# </tr>
# <tr>
# <td>Mia Junior</td>
# <td>4500</td>
# </tr>
# <tr>
# <td>Sophia Depp</td>
# <td>3600</td>
# </tr>
# <tr>
# <td>James Smith</td>
# <td>5596</td>
# </tr>
#
# </table>

# %%
md1 ={
    'Name' : ['Emma Larter','Mia Junior','Sophia Depp','James Smith'],
    'Salary' : [3200,4500,3600,5596]
} 
df3 = pd.DataFrame(md1)

df3[['First_Name','Last_Name']] = df3.Name.str.split(expand=True)
df3.drop(columns='Name',inplace=True)
df3
# Out:
#    Salary First_Name Last_Name
# 0    3200       Emma    Larter
# 1    4500        Mia    Junior
# 2    3600     Sophia      Depp
# 3    5596      James     Smith

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>4. Select the rows from below dataframe where marks are less than 60 </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Marks</th>
# </tr>
# <tr>
# <td>John</td>
# <td>90</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>50</td>
# </tr>
# <tr>
# <td>Jonny</td>
# <td>89</td>
# </tr>
# <tr>
# <td>Mia</td>
# <td>55</td>
# </tr>
#
# </table>

# %%
md12 ={
    'Name' : ['John', 'Robert', 'Jonny', 'Mia'],
    'marks' : [90,50,89,55]
} 
df14 = pd.DataFrame(md12)
df4=df14[df14.marks<60]
print(df4)
# Out:
#      Name  marks
# 1  Robert     50
# 3     Mia     55

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>5. Write a program to select the rows where the sales are higher than 60000 for Mumbai </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
md5={ 
     'store': ['A','B','A','C','D','A','D','A','C','B'],
     'Location':['Mumbai','Pune','Hyderabad','Mumbai','Pune','Delhi','Hyderabad','Pune','Mumbai','Pune'],
     'Sales': [40000,45000,50000,90000,89000,87000,85000,78000,89000,70000]
}
df15 = pd.DataFrame(md5)
df5=df15[(df15.Sales>60000) & (df15.Location == 'Mumbai')]
print(df5)
# Out:
#   store Location  Sales
# 3     C   Mumbai  90000
# 8     C   Mumbai  89000

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>6. Write a program to select stores located in Hyderabad</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
md5={ 
     'store': ['A','B','A','C','D','A','D','A','C','B'],
     'Location':['Mumbai','Pune','Hyderabad','Mumbai','Pune','Delhi','Hyderabad','Pune','Mumbai','Pune'],
     'Sales': [40000,45000,50000,90000,89000,87000,85000,78000,89000,70000]
}
df15 = pd.DataFrame(md5)
df5=df15[df15.Location == 'Hyderabad']
print(df5)
# Out:
#   store   Location  Sales
# 2     A  Hyderabad  50000
# 6     D  Hyderabad  85000

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>7. Write a program to replace the 'Store' column with the values A, B, C, and D with Store_A,  Store_B, Store_C and Store_D respectively </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
md5={ 
     'store': ['A','B','A','C','D','A','D','A','C','B'],
     'Location':['Mumbai','Pune','Hyderabad','Mumbai','Pune','Delhi','Hyderabad','Pune','Mumbai','Pune'],
     'Sales': [40000,45000,50000,90000,89000,87000,85000,78000,89000,70000]
}
df15 = pd.DataFrame(md5)
mydf={'A':'Store_A',
     'B':'Store_B',
     'C':'Store_C',
     'D':'Store_D'
    
}
df15.store.replace(mydf,inplace=True)       

df15
# Out:
#      store   Location  Sales
# 0  Store_A     Mumbai  40000
# 1  Store_B       Pune  45000
# 2  Store_A  Hyderabad  50000
# 3  Store_C     Mumbai  90000
# 4  Store_D       Pune  89000
# 5  Store_A      Delhi  87000
# 6  Store_D  Hyderabad  85000
# 7  Store_A       Pune  78000
# 8  Store_C     Mumbai  89000
# 9  Store_B       Pune  70000

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>8. Create a dataframe in pandas using the given list.
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the below list**
#
#         city = ['Delhi', 'Mumbai', 'Chennai', 'Kolkata']

# %%
city = ['Delhi', 'Mumbai', 'Chennai', 'Kolkata']
df18 = pd.DataFrame(city)
df18
# Out:
#          0
# 0    Delhi
# 1   Mumbai
# 2  Chennai
# 3  Kolkata

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>9. Save a given dataframe to a csv file
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
df9 = pd.read_csv('df_store.csv', index_col=0)
df9
# Out:
#   Store   Location  Sales
# 0     A     Mumbai  40000
# 1     B       Pune  45000
# 2     A  Hyderabad  56000
# 3     C     Mumbai  90000
# 4     D       Pune  89000
# 5     A      Delhi  87000
# 6     D  Hyderabad  85000
# 7     A       Pune  78000
# 8     C     Mumbai  89000
# 9     B       Pune  70000

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>10. Find the maximum sales for each store
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
df15
df15.groupby(by= ['Location','store']).max()
# Out:
#                    Sales
# Location  store
# Delhi     Store_A  87000
# Hyderabad Store_A  50000
#           Store_D  85000
# Mumbai    Store_A  40000
#           Store_C  90000
# Pune      Store_A  78000
#           Store_B  70000
#           Store_D  89000

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>11. Write a program to select all columns, except the 'Location' from the given dataframe
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
df15.loc[:,df15.columns!='Location']
# Out:
#      store  Sales
# 0  Store_A  40000
# 1  Store_B  45000
# 2  Store_A  50000
# 3  Store_C  90000
# 4  Store_D  89000
# 5  Store_A  87000
# 6  Store_D  85000
# 7  Store_A  78000
# 8  Store_C  89000
# 9  Store_B  70000

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>12. Write a program to insert a given column at the second position in a dataframe
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Age</th>
# </tr>
# <tr>
# <td>Emma Larter</td>
# <td>34</td>
# </tr>
# <tr>
# <td>Mia Junior</td>
# <td>59</td>
# </tr>
# <tr>
# <td>Sophia Depp</td>
# <td>32</td>
# </tr>
# <tr>
# <td>James Smith</td>
# <td>40</td>
# </tr>
#
# </table>
#
# **Add the variable 'Salary' as second column**<br>
#
#             Salary = [35000, 24000, 55000, 40000]

# %%
md1 ={
    'Name' : ['Emma Larter','Mia Junior','Sophia Depp','James Smith'],
    'Age' : [34,59,32,40]
} 
df3 = pd.DataFrame(md1)
salary_value = [35000, 24000, 55000, 40000]
df3.insert(2,'Salary',salary_value)
df3
# Out:
#           Name  Age  Salary
# 0  Emma Larter   34   35000
# 1   Mia Junior   59   24000
# 2  Sophia Depp   32   55000
# 3  James Smith   40   40000

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>13. Write a program to get the third observation of the given dataframe
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Age</th>
# </tr>
# <tr>
# <td>Emma Larter</td>
# <td>34</td>
# </tr>
# <tr>
# <td>Mia Junior</td>
# <td>59</td>
# </tr>
# <tr>
# <td>Sophia Depp</td>
# <td>32</td>
# </tr>
# <tr>
# <td>James Smith</td>
# <td>40</td>
# </tr>
# </table>

# %%
md1 ={
    'Name' : ['Emma Larter','Mia Junior','Sophia Depp','James Smith'],
    'Age' : [34,59,32,40]
} 
df3 = pd.DataFrame(md1)
df3[2:3]
# Out:
#           Name  Age
# 2  Sophia Depp   32

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>14. Write a program to create a dataframe from the provided lists</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the following lists to create your arrays:**
#
#             columns = ["Science", "Maths", "English"]
#
#             marks = [[55, 78, 88], [93, 63, 83],[94, 74, 64]]
#
# **Hint:** Convert the list marks into an array

# %%
cl = ["Science", "Maths", "English"]

import numpy as np
marks = [[55, 78, 88], [93, 63, 83],[94, 74, 64]]
n=np.array(marks)
df14=pd.DataFrame(n,columns=cl)
df14
# Out:
#    Science  Maths  English
# 0       55     78       88
# 1       93     63       83
# 2       94     74       64

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>15. Write a program to count total sales per store </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
df15
df15.groupby(by= 'store').sum()
# Out:
#           Sales
# store
# Store_A  255000
# Store_B  115000
# Store_C  179000
# Store_D  174000

# %% [markdown]
# <a id='sorting'></a>
# ## 3. Sort

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>16. Write a program to sort the dataframe by 'Sales' in ascending order
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
df2=df15.sort_values(by='Sales', ascending=True)
df2
# Out:
#      store   Location  Sales
# 0  Store_A     Mumbai  40000
# 1  Store_B       Pune  45000
# 2  Store_A  Hyderabad  50000
# 9  Store_B       Pune  70000
# 7  Store_A       Pune  78000
# 6  Store_D  Hyderabad  85000
# 5  Store_A      Delhi  87000
# 4  Store_D       Pune  89000
# 8  Store_C     Mumbai  89000
# 3  Store_C     Mumbai  90000

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>17. Write a program to sort the dataframe by 'Store' in ascending order and by 'Sales' in descending order with respect to store simultaneously
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
# type your code here
df2=df15.sort_values(by=['store','Sales'], ascending=[True,False])
df2
# Out:
#      store   Location  Sales
# 5  Store_A      Delhi  87000
# 7  Store_A       Pune  78000
# 2  Store_A  Hyderabad  50000
# 0  Store_A     Mumbai  40000
# 9  Store_B       Pune  70000
# 1  Store_B       Pune  45000
# 3  Store_C     Mumbai  90000
# 8  Store_C     Mumbai  89000
# 4  Store_D       Pune  89000
# 6  Store_D  Hyderabad  85000

# %% [markdown]
# <a id='ranking'></a>
# ## 4. Rank

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>18. Create a column 'Rank_sales' which contains the rank of each store based on sales of the product in ascending order
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
df15['Rank_sales']=df15.Sales.rank(ascending=True)
df15
# Out:
#      store   Location  Sales  Rank_sales
# 0  Store_A     Mumbai  40000         1.0
# 1  Store_B       Pune  45000         2.0
# 2  Store_A  Hyderabad  50000         3.0
# 3  Store_C     Mumbai  90000        10.0
# 4  Store_D       Pune  89000         8.5
# 5  Store_A      Delhi  87000         7.0
# 6  Store_D  Hyderabad  85000         6.0
# 7  Store_A       Pune  78000         5.0
# 8  Store_C     Mumbai  89000         8.5
# 9  Store_B       Pune  70000         4.0
