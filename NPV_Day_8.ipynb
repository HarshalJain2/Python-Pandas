# %% [markdown]
# ### Let's begin with some hands-on practice exercises

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 1. Plot a horizontal bar chart and vertical bar chart for the following data.
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table>
# <tr>
#     <th>Name</th>
#     <td>Sheldon</td>
#     <td>Amy</td>
#     <td>Priya</td>
#     <td>Raj</td>
# </tr>
# <tr>
#     <th>Maths</th>
#     <td>72</td>
#     <td>34</td>
#     <td>54</td>
#     <td>76</td>
# </tr>
# <tr>
#     <th>Geography</th>
#     <td>98</td>
#     <td>98</td>
#     <td>78</td>
#     <td>87</td>
#   </tr>
# </table>

# %%
Maths=[72,34,54,76]
Geogr=[98,98,78,87]
name=['sheldon','amy','priya','raj']
df = pd.DataFrame({'Maths': Maths,
                   'Geogr': Geogr}, index=name,)
ax = df.plot.barh()
bx = df.plot.bar()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 2. Following is data on 10 people, information on the number of dependents on each of them and their income is given. Draw a dual-axis plot.
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table>
# <tr>
#     <th>Person</th>
#     <td>No. of Dependents</td>
#     <td>Income</td>
# </tr>
# <tr>
#     <th>1</th>
#     <td>1</td>
#     <td>60000</td>
# </tr>
# <tr>
#     <th>2</th>
#     <td>2</td>
#     <td>52000</td>
# </tr>
# <tr>
#     <th>3</th>
#     <td>0</td>
#     <td>50000</td>
# </tr>
# <tr>
#     <th>4</th>
#     <td>3</td>
#     <td>65000</td>
# </tr>
# <tr>
#     <th>5</th>
#     <td>0</td>
#     <td>45500</td>
# </tr>
# <tr>
#     <th>6</th>
#     <td>1</td>
#     <td>43050</td>
# </tr>
# <tr>
#     <th>7</th>
#     <td>0</td>
#     <td>54300</td>
# </tr>
# <tr>
#     <th>8</th>
#     <td>0</td>
#     <td>38000</td>
# </tr>
# <tr>
#     <th>9</th>
#     <td>2</td>
#     <td>20000</td>
# </tr>
# <tr>
#     <th>10</th>
#     <td>1</td>
#     <td>47500</td>
#     </tr>
# </table>

# %%
y1=[1,2,0,3,0,1,0,0,2,1]
y2=[60000,52000,50000,65000,45500,43050,54300,38000,20000,47500]
plt.plot(y1,y1, marker='*')
plt.plot(y1,y2, marker='^')

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 3. Use the following data to plot a pie chart and annotate the percentage sales.
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table>
#   <tr>
#   <th>Location</th>
#   <th>Sale</th>
#   </tr>
#   <tr>
#   <td>Delhi</td>
#   <td>42500</td>
#   </tr>
#   <tr>
#   <td>Bangalore</td>
#   <td>44500</td>
#   </tr>
#   <tr>
#   <td>Chennai</td>
#   <td>48300</td>
#   </tr>
#   <tr>
#   <td>Pune</td>
#   <td>52400</td>
#   </tr>
#   <tr>
#   <td>Kolkata</td>
#   <td>61800</td>
#   </tr>
# </table>

# %%
sale=[42500,44500,48300,52400,61800]
loca=['delhi','banglore','chennai','pune','kolkata']
plt.pie(x=sale,labels= loca,autopct='%.1f')
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 4. Write a program to plot a bar plot of seven students representing their marks in Mathematics using plotly.
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
#         marks = [76,98,78,98,89,56,69,76]
#         students = ['Sheldon','Leonard','Raj','Howard','Amy','Penny','Bernadette']

# %%
marks = [76,98,78,98,89,56,69]
students = ['Sheldon','Leonard','Raj','Howard','Amy','Penny','Bernadette']

xpos = np.arange(len(students))
print(xpos)

plt.bar(students, marks , color = 'red', label = 'marks' , width=0.4 )
# Out:
# [0 1 2 3 4 5 6]
# <BarContainer object of 7 artists>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 5. Import the flights data set and plot a line plot for the variable 'passengers'.
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df5=sns.load_dataset('flights')
print(df5)
sns.lineplot(data=df5.passengers)
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]
# <AxesSubplot:ylabel='passengers'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 6. Import the iris data set and plot a heatmap of the correlation between its numeric variables.
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df6=sns.load_dataset('iris')
cmat=df6.corr()
cmat
plt.figure(figsize=(4,3),dpi=100)
sns.heatmap(cmat,annot=True, cmap='rainbow_r')
plt.savefig('heatmap.png')

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 7. Using the iris data set, plot boxplot of its numeric features.
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df7=sns.load_dataset('iris')
sns.boxplot(data=df7)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 8. Import the built-in 'diamonds' data set from seaborn. For the variable 'cut', plot a count plot.
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df8=sns.load_dataset('diamonds')
print(df8)
sns.countplot(x='cut',data=df8)
plt.show()
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 9. Use the iris data set, to plot a joint plot of sepal length against sepal width.
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df9 = sns.load_dataset('iris')
print(df9)

sns.jointplot(data=df9 , x = 'sepal_length' , y = 'sepal_width')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 10. Jake's monthly expenditure is given below. Draw a pie chart and explode the wedge with highest cost
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table>
#     <tr>
#         <th> Item  </th>
#         <th> Expenditure </th>
#     </tr>
#     <tr>
#         <th> Food </th>
#         <th> 15</th>
#     </tr>
#     <tr>
#         <th> Clothing </th>
#         <th> 10</th>
#     </tr>
#     <tr>
#         <th> Rent </th>
#         <th> 40 </th>
#     </tr>
#     <tr>
#         <th> Education </th>
#         <th> 25</th>
#     </tr>
#     <tr>
#         <th> Unforseen Events </th>
#         <th> 5</th>
#     </tr>
#     <tr>
#         <th> Medicine </th>
#         <th>5</th>
#     </tr>
# </table>

# %%
df10 = pd.read_csv('q10.csv')
print(df10)

vc = df10.Expenditure.value_counts()
vc

plt.pie(x=vc.values, labels=vc.index, autopct='%.2f', explode=[0,0,0,0.5,0])
# Out:
#                Item  Expenditure
# 0              Food           15
# 1          Clothing           10
# 2              Rent           40
# 3         Education           25
# 4  Unforseen Events            5
# 5          Medicine            5
# ([<matplotlib.patches.Wedge at 0x2aeea2a7c70>,
#   <matplotlib.patches.Wedge at 0x2aeea177820>,
#   <matplotlib.patches.Wedge at 0x2aeea177d30>,
#   <matplotlib.patches.Wedge at 0x2aeea2a1d30>,
#   <matplotlib.patches.Wedge at 0x2aeea2a19d0>],
#  [Text(0.5499999702695115, 0.9526279613277875, '5'),
#   Text(-0.9526279870751434, 0.5499999256737774, '15'),
#   Text(-0.952627884085708, -0.5500001040567056, '10'),
#   Text(2.2470421725014237e-07, -1.5999999999999843, '40'),
#   Text(0.9526280385698485, -0.5499998364823061, '25')],
#  [Text(0.2999999837833699, 0.5196152516333385, '33.33'),
#   Text(-0.5196152656773508, 0.299999959458424, '16.67'),
#   Text(-0.5196152095012951, -0.30000005675820307, '16.67'),
#   Text(1.5448414935947285e-07, -1.0999999999999892, '16.67'),
#   Text(0.5196152937653719, -0.29999991080853056, '16.67')])
